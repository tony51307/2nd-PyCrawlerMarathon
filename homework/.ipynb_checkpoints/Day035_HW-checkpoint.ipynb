# %% [markdown]
# # 加速：多線程爬蟲
#
#
#
# * 了解知乎 API 使用方式與回傳內容
# * 撰寫程式存取 API 且添加標頭

# %% [markdown]
# ## 作業目標
#
# * 找一個之前實作過的爬蟲改用多線程改寫，比較前後時間的差異。

# %%
import requests
import _thread
import time
from bs4 import BeautifulSoup

start=time.time()
r=requests.get('https://www.ptt.cc/bbs/studyabroad/index.html')
soup=BeautifulSoup(r.text)
for d in soup.find_all('div',class_='r-ent'):
    print('作者： '+str(d.find(class_='meta').find(class_='author').text))
    print('標題： '+str(d.find(class_='title').text).replace('\n',''))
    print('日期： '+str(d.find(class_='meta').find(class_='date').text))
    print()
stop=time.time()
print(stop-start)
# Out:
# 作者： miyazako
# 標題： [心得] 七分鐘學會如何尋找國外研究所的Program
# 日期：  4/04
#
# 作者： erictaur
# 標題： [選校] UCSD BME PhD/UPenn MSEE
# 日期：  4/04
#
# 作者： weiwei1919
# 標題： [選校] UCLA/UW-Madison/UIUC MSCS/MCS 選校
# 日期：  4/04
#
# 作者： physics11
# 標題： [問題] 申請化工領域的苦惱
# 日期：  4/05
#
# 作者： PyTorch
# 標題： Re: [問題] 申請化工領域的苦惱
# 日期：  4/05
#
# 作者： brianlee0724
# 標題： [選校] Umich HI/UNC chapel hill BMHI master
# 日期：  4/05
#
# 作者： jeremy199690
# 標題： [錄取] MSE/EE/Nano TU Delft/EPFL/KTH/UCLA/KU
# 日期：  4/05
#
# 作者： ryanpaul1021
# 標題： Re: [問題] 申請化工領域的苦惱
# 日期：  4/05
#
# 作者： tpmlref5
# 標題： [情報] 4/12北市圖線上講座
# 日期：  4/05
#
# 作者： Iam793
# 標題： [尋人] Cornell Tech 2020 Fall
# 日期：  4/05
#
# 作者： joshua40302
# 標題： Re: [問題] 申請化工領域的苦惱
# 日期：  4/05
#
# 作者： tzyyshyang
# 標題： Re: [問題] 申請化工領域的苦惱
# 日期：  4/05
#
# 作者： void
# 標題： Re: [問題] 申請化工領域的苦惱
# 日期：  4/05
#
# 作者： ron0908
# 標題： [公告] 買賣書籍/團報/課程  請統一推文
# 日期： 12/20
#
# 作者： ron0908
# 標題： [公告] 新手常見Q&A (不定時補完)
# 日期：  9/05
#
# 作者： aznchat100
# 標題： Re: [情報] 留學版全文搜尋工具(持續更新)
# 日期：  5/11
#
# 作者： ron0908
# 標題： Re: [公告] 留學板板規v2.3 (2018.08.05修改)
# 日期：  8/05
#
# 作者： ron0908
# 標題： Re: [公告] 開放admission, rejection推文
# 日期：  1/05
#
# 0.919342041015625

# %%
start=time.time()
r=requests.get('https://www.ptt.cc/bbs/studyabroad/index.html')
soup=BeautifulSoup(r.text)

def print_info(d):
    for d in soup.find_all('div',class_='r-ent'):
        print()
        print('作者： '+str(d.find(class_='meta').find(class_='author').text))
        print('標題： '+str(d.find(class_='title').text).replace('\n',''))
        print('日期： '+str(d.find(class_='meta').find(class_='date').text))
        print()


_thread.start_new_thread(print_info, (d, ))
stop=time.time()
print(stop-start)
# Out:
# 0.30740904808044434
#
# 作者： miyazako
# 標題： [心得] 七分鐘學會如何尋找國外研究所的Program
# 日期：  4/04
#
#
# 作者： erictaur
# 標題： [選校] UCSD BME PhD/UPenn MSEE
# 日期：  4/04
#
#
# 作者： weiwei1919
# 標題： [選校] UCLA/UW-Madison/UIUC MSCS/MCS 選校
# 日期：  4/04
#
#
# 作者： physics11
# 標題： [問題] 申請化工領域的苦惱
# 日期：  4/05
#
#
# 作者： PyTorch
# 標題： Re: [問題] 申請化工領域的苦惱
# 日期：  4/05
#
#
# 作者： brianlee0724
# 標題： [選校] Umich HI/UNC chapel hill BMHI master
# 日期：  4/05
#
#
# 作者： jeremy199690
# 標題： [錄取] MSE/EE/Nano TU Delft/EPFL/KTH/UCLA/KU
# 日期：  4/05
#
#
# 作者： ryanpaul1021
# 標題： Re: [問題] 申請化工領域的苦惱
# 日期：  4/05
#
#
# 作者： tpmlref5
# 標題： [情報] 4/12北市圖線上講座
# 日期：  4/05
#
#
# 作者： Iam793
# 標題： [尋人] Cornell Tech 2020 Fall
# 日期：  4/05
#
#
# 作者： joshua40302
# 標題： Re: [問題] 申請化工領域的苦惱
# 日期：  4/05
#
#
# 作者： tzyyshyang
# 標題： Re: [問題] 申請化工領域的苦惱
# 日期：  4/05
#
#
# 作者： void
# 標題： Re: [問題] 申請化工領域的苦惱
# 日期：  4/05
#
#
# 作者： ron0908
# 標題： [公告] 買賣書籍/團報/課程  請統一推文
# 日期： 12/20
#
#
# 作者： ron0908
# 標題： [公告] 新手常見Q&A (不定時補完)
# 日期：  9/05
#
#
# 作者： aznchat100
# 標題： Re: [情報] 留學版全文搜尋工具(持續更新)
# 日期：  5/11
#
#
# 作者： ron0908
# 標題： Re: [公告] 留學板板規v2.3 (2018.08.05修改)
# 日期：  8/05
#
#
# 作者： ron0908
# 標題： Re: [公告] 開放admission, rejection推文
# 日期：  1/05
